# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn import linear_model
from sklearn import metrics


from google.colab import drive

# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd
import tensorboard as tb

# %%
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Proyecto Python_JaimeM ')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Descarga de datos de casas
data = np.load('proyecto_training_data.npy')

variables = ['SalePrice','OverallQual','1stFlrSF','TotRmsAbvGrd','YearBuilt','LotFrontage']
dataframe = pd.DataFrame(data, columns = variables)


corespondencia = {'SalePrice':0,'OverallQual':1,'1stFlrSF':2,'TotRmsAbvGrd':3,'YearBuilt':4,'LotFrontage':5}

# %%
# Mismos sets de datos convertidos en dataframes
variables = ['SalePrice','OverallQual','1stFlrSF','TotRmsAbvGrd','YearBuilt','LotFrontage']
df = pd.DataFrame(data, columns = variables)

x = df['OverallQual']
y = df['SalePrice']


def gradiente_desc(SalePrice, OverallQual, ini_pend, ini_intercep, lr):
 
    tf_pendiente = tf.variable(ini_pend) 
    tf_intercep = tf.variable(ini_intercep) 
    
    # iteraciones del gradiente descente
    for i in range(250):
        with tf.GradientTape() as tape:
            tape.watch((tf_pendiente, tf_intercep))

            # calculando error MSE
            prediccion = tf_pendiente * SalePrice + tf_intercep
            error = prediccion - OverallQual
            loss = tf.reduce_mean(error**2)

        #Calculo del gradiente del error respecto a los parametros
        dloss_dparams = tape.gradient(loss, [tf_pendiente, tf_intercep])
       
        tf_pendiente = tf_pendiente - lr * dloss_dparams[0]
        tf_intercep = tf_intercep - lr * dloss_dparams[1]
        print(tf_pendiente, tf_intercep)
        
    return loss, tf_pendiente, tf_intercep

    print(tf_pendiente, tf_intercep)

# %%
  #intentando graficarlos con numpy
    x_numpy = x.numpy()
    y_numpy = y.numpy()
# Out:
#   File "<ipython-input-13-0572607f01c4>", line 2
#     x_numpy = x.numpy()
#     ^
# IndentationError: unexpected indent
